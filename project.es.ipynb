# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
precio_max= ds['price'].max()
condicion = ds['price'] == precio_max
busqueda = ds[condicion]

direccion_max = busqueda['address'].iloc[0]

print (f"La casa con dirección {direccion_max} es la más cara y su precio es de {precio_max} USD")

print (precio_max)
print (direccion_max)
# Out:
# La casa con dirección El Escorial es la más cara y su precio es de 8500000 USD
# 8500000
# El Escorial

# %% [markdown]
# ** Después de haber visto la clase, sé que podríamos haberlo resuelto con un print(ds['address'][ds['price'].max()])

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
precio_min= ds['price'].min()
condicion = ds['price'] == precio_min
busqueda = ds[condicion]
direccion_min = busqueda['address'].iloc[0]

print(precio_min)
print (f"La casa con dirección {direccion_min} es la más barata y su precio es de {precio_min} USD")
# Out:
# 0
# La casa con dirección Parla es la más barata y su precio es de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO

superficie_max= ds['surface'].max()
condicion = ds['surface'] == superficie_max
busqueda = ds[condicion]
direccion_supmax = busqueda['address'].iloc[0]

superficie_min= ds['surface'].min()
condicion = ds['surface'] == superficie_min
busqueda = ds[condicion]
direccion_supmin = busqueda['address'].iloc[0]

print(superficie_max)
print(direccion_supmax)
print (f"La casa más grande está ubicada en {direccion_supmax} y su superficie es de {superficie_max} metros")
print (f"La casa más pequeña está ubicada en {direccion_supmin} y su superficie es de {superficie_min} metros")
# Out:
# 249000.0
# Sevilla la Nueva
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
recuento = ds['level5'].value_counts()
recuento_poblacion = recuento.index.tolist()

print(recuento_poblacion)
print(recuento)
# Out:
# [' Madrid Capital', 'Alcalá de Henares', 'Las Rozas de Madrid', 'Móstoles', 'Getafe', 'San Sebastián de los Reyes', 'Boadilla del Monte', 'Parla', 'Valdemoro', 'Torrejón de Ardoz', 'Pozuelo de Alarcón', 'Alcobendas', 'Fuenlabrada', 'Collado Villalba', 'Arganda del Rey', 'Leganés', 'Alcorcón', 'Coslada', 'Villaviciosa de Odón', 'Pinto', 'Majadahonda', 'Aranjuez', 'Arroyomolinos (Madrid)', 'Rivas-vaciamadrid', 'Torrelodones', 'Navalcarnero', 'El Escorial', 'Ciempozuelos', 'Galapagar', 'Velilla de San Antonio', 'Moralzarzal', 'San Lorenzo de El Escorial', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'San Martín de la Vega', 'Colmenar Viejo', 'El Álamo', 'Villalbilla', 'Miraflores de la Sierra', 'Humanes de Madrid', 'Alpedrete', 'Valdemorillo', 'Mejorada del Campo', 'Torrejón de la Calzada', 'Paracuellos de Jarama', 'Guadarrama', 'San Fernando de Henares', 'Meco', 'Camarma de Esteruelas', 'Tres Cantos', 'Algete', 'San Martín de Valdeiglesias', 'Robledo de Chavela', 'El Molar (Ma
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
valores_nulos = ds.isnull()
columnas_nulas = ds.columns[ds.isnull().any()]

print(valores_nulos)
print(columnas_nulas)
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
data_limpia = ds.dropna()

print(data_limpia.shape)
print(ds.shape)

print(data_limpia)
# Out:
# (0, 37)
# (15335, 37)
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO

ds_arroyomolinos = ds.loc[ds['level5'] == 'Arroyomolinos (Madrid)']
media_precios = int(ds_arroyomolinos['price'].mean())

print(ds_arroyomolinos)
print (media_precios)
# Out:
#        Unnamed: 0  id_realEstates  isNew                  realEstate_name  \
# 453           454       153843083  False                  akris arguelles
# 607           608       153620088  False        100 home red inmobiliaria
# 613           614       153478908  False               mares inmobiliaria
# 707           708       153736961  False                         gm house
# 852           853       153274493  False                         gm house
# ...           ...             ...    ...                              ...
# 15019       15020       152767314  False                 haya real estate
# 15089       15090       152767395  False                 haya real estate
# 15091       15092       152767377  False                 haya real estate
# 15094       15095       152767335  False                 haya real estate
# 15192       15193       146831440  False  miranda servicios inmobiliarios
#
#        phone_realEstate                                       url_inmueble  \
# ...

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt

ds_arroyomolinos = ds.loc[ds['level5'] == 'Arroyomolinos (Madrid)']
ds_arroyomolinos['price'].hist(bins=15, grid = False)

plt.title('Precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Se puede ver que la mayoría de datos se agrupan en un intervalo de precios entre los 200000 y los 300000€ de coste. Podríamos decir que la adquisición de una vivienda de Arroyomolinos puede ir entorno a estos precios.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
ds_valdemorillo = ds.loc[ds['level5'] == 'Valdemorillo']
media_precios_valde = int(ds_valdemorillo['price'].mean())

ds_galapagar = ds.loc[ds['level5'] == 'Galapagar']
media_precios_galapagar = int(ds_galapagar['price'].mean())

print(media_precios_galapagar)
print(media_precios_valde)
# Out:
# 360063
# 363860

# %% [markdown]
# La diferencia existente de precios es de casi 4000€, no parece significativo para las cantidades existentes si de adquisición de vivienda se trata. Considero que son bastante similares ambas poblaciones.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
ds["pps"] = ds['price'] / ds['surface']

ds_valdemorillo = ds.loc[ds['level5'] == 'Valdemorillo']
media_pps_valde = int(ds_valdemorillo['pps'].mean())

ds_galapagar = ds.loc[ds['level5'] == 'Galapagar']
media_pps_galapagar = int(ds_galapagar['pps'].mean())

print(ds.columns)
print(ds["pps"])
print (media_pps_galapagar)
print(media_pps_valde)
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone', 'pps'],
#       dtype='object')
# 0        1893.203883
# 1                NaN
# 2        3939.393939
# 3        1034.883721
# 4        1622.641509
#             ...
# 15330    2702.812500
# 15331    1100.000000
# 15332    2828.571429
# 15333    1930.693069
# 15334    5032.894737
# Name: pps, Length: 15335, dtype: float64
# 1606
# 1317

# %% [markdown]
# El precio por metro cuadrado es mucho más económico en Valdemorillo que en Galapagar. A pesar que la media de precios es bastante similar, el precio por metro cuadrado hace la diferencia, puesto que se podrán conseguir viviendas de buen tamaño a mejor precio.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código

import matplotlib.pyplot as plt
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')

x = ds['surface']
y = ds['price']
plt.scatter( x, y, marker='o', color='red')

plt.xlim(0, 800)
plt.ylim(0, 750000)

plt.xlabel('Superficie')
plt.ylabel('Precio')
plt.title('Superficie vs precio')

print(ds['price'])
print(ds['surface'])
# Out:
# 0        195000
# 1         89000
# 2        390000
# 3         89000
# 4        172000
#           ...
# 15330    259470
# 15331    165000
# 15332    495000
# 15333    195000
# 15334    765000
# Name: price, Length: 15335, dtype: int64
# 0        103.0
# 1          NaN
# 2         99.0
# 3         86.0
# 4        106.0
#          ...
# 15330     96.0
# 15331    150.0
# 15332    175.0
# 15333    101.0
# 15334    152.0
# Name: surface, Length: 15335, dtype: float64

# %% [markdown]
# Tuve que modificar los límites de cada variable para poder ver el registro de dispersión de puntos. Aún no se ven claros los rangos en los que se mueve cada uno pero si es visible el hecho que entre los 100-300mts de superficie, el aumento de precio es inminente. Sin embargo, parecen haber zonas en las que, independientemente de la superficie, el precio es cero (no puedo ver la lista de datos). También existen otras pequeñas zonas cuyo precio aumenta más gradualmente por su metraje, estaría bien evaluar estas zonas en las que el precio está mejor compensado por la superficie.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

conteo_repetidos = ds['realEstate_name'].value_counts()
total_agencias = conteo_repetidos.sum()
total_unicas = conteo_repetidos.nunique()

print(ds.columns)
print(conteo_repetidos)
print(total_agencias)
print(total_unicas)
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')
# realEstate_name
# engel volkers madrid    470
# infocasa consulting     300
# outletdeviviendas       260
# housell                 250
# solvia inmobiliaria     207
#                        ...
# inmonorte                 1
# pedro angel               1
# city madrid               1
# copernicus servicing      1
# active inmobiliaria       1
# Name: count, Length: 1821, dtype: int64
# 15325
# 78

# %% [markdown]
# El total es de 78 inmobiliarias distintas. Totales que aparecen son de 15325 agencias.

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

ds_casas_poblacion = ds['level5'].value_counts()
poblacion_max = ds_casas_poblacion.idxmax()
casas_max = ds_casas_poblacion.max()

print(ds_casas_poblacion)
print(poblacion_max)
print(casas_max)
# Out:
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Fresno de Torote           1
# Pinilla del Valle          1
# Rascafría                  1
# La Hiruela                 1
# Montejo de la Sierra       1
# Name: count, Length: 168, dtype: int64
#  Madrid Capital
# 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO

ds_cinturon_sur = ds['level5'].isin(['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón'])
data_sur = ds[ds_cinturon_sur]

print(ds_cinturon_sur)
print (data_sur)
print (data_sur.shape)
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 15330    False
# 15331    False
# 15332    False
# 15333    False
# 15334    False
# Name: level5, Length: 15335, dtype: bool
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
import matplotlib.pyplot as plt

data_sur = ds[ds_cinturon_sur]
mediana_precios_poblacion = data_sur.groupby('level5')['price'].median()

mediana_precios_poblacion.plot (kind='bar')
print(mediana_precios_poblacion)

plt.xlabel('Población')
plt.ylabel('Mediana de precios')
plt.title('Precios vs Población')
# Out:
# level5
# Alcorcón       179500.0
# Fuenlabrada    155000.0
# Getafe         285305.0
# Leganés        169950.0
# Name: price, dtype: float64
# Text(0.5, 1.0, 'Precios vs Población')

# %% [markdown]
# Considerando que la mediana no es susceptible a valores extremos, es de pensar que Getafe contiene la mayor proproción de casas de mayor valor de todas en el cinturón sur de Madrid.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO

data_sur = ds[ds_cinturon_sur]
precios_var = data_sur['price'].var()
precios_media = data_sur['price'].mean()

habitaciones_media = data_sur['rooms'].mean()
habitaciones_var = data_sur['rooms'].var()

superficie_media =data_sur['surface'].mean()
superficie_var = data_sur['surface'].var()

banios_media =data_sur['bathrooms'].mean()
banios_var =data_sur['bathrooms'].var()

print(habitaciones_media)
print(habitaciones_var)
print(precios_media)
print(precios_var)
# Out:
# 3.0177383592017737
# 0.7188858892927542
# 223094.48070562293
# 14921367508.04902

# %% [markdown]
# Hay algo en el cálculo de la varianza en los precios que no está correcto, arroja un número de 11 cifras cuando los precios tienen 6 cifras. No pude determinar a qué se debe.

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO

data_sur = ds[ds_cinturon_sur]
casa_cara_poblacion = data_sur.groupby('level5')['price'].max()
direccion_maxima = data_sur.loc[data_sur.groupby('level5')['price'].idxmax()]

print(direccion_maxima[['level5', 'price', 'address']])
print(casa_cara_poblacion)
# Out:
#             level5    price                                address
# 5585      Alcorcón   950000                               Alcorcón
# 11561  Fuenlabrada   490000  Calle de Paulo Freire, 5, Fuenlabrada
# 2881        Getafe  1050000                                 Getafe
# 10412      Leganés   650000           Avenida Reina Sofía, Leganés
# level5
# Alcorcón        950000
# Fuenlabrada     490000
# Getafe         1050000
# Leganés         650000
# Name: price, dtype: int64

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
import matplotlib.pyplot as plt
data_sur = ds[ds_cinturon_sur]

data_sur['precio_normal'] = data_sur.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

data_sur.groupby('level5')['precio_normal'].plot.hist(legend = True)

plt.title('Precios normalizados por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')

print(data_sur['precio_normal'])
# Out:
# /tmp/ipykernel_503/2913221147.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sur['precio_normal'] = data_sur.groupby('level5')['price'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
# 1        0.000000
# 3        0.000000
# 85       0.018055
# 94       0.440678
# 109      0.388468
#            ...
# 15275    0.122195
# 15291    0.371186
# 15305    0.201995
# 15322    0.057357
# 15325    0.314214
# Name: precio_normal, Length: 907, dtype: float64

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
data_sur = ds[ds_cinturon_sur]
data_sur['pps2'] = data_sur['price'] / data_sur['surface']

data_poblacion_pps2 = data_sur.groupby('level5')['pps2'].mean()



print(data_sur['pps2'])
print(data_poblacion_pps2)
# Out:
# 1                NaN
# 3        1034.883721
# 85       2140.000000
# 94       2666.666667
# 109      2992.957746
#             ...
# 15275    1769.230769
# 15291    2536.363636
# 15305    2000.000000
# 15322    1230.769231
# 15325    2171.717172
# Name: pps2, Length: 907, dtype: float64
# level5
# Alcorcón       2239.302480
# Fuenlabrada    1796.729220
# Getafe         2066.314949
# Leganés        2047.503268
# Name: pps2, dtype: float64
# /tmp/ipykernel_514/1596927956.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sur['pps2'] = data_sur['price'] / data_sur['surface']

# %% [markdown]
# Para poderlo ver tuve que calcular la media de cada población. No tenía muy claro si tenia que sacar un series o un array con todos los valores de cada población. En cualquier caso, obtuve un número con el que pudiera establecer alguna comparación.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
data_sur = ds[ds_cinturon_sur]

data_alcorcon = data_sur[data_sur['level5'] == 'Alcorcón']
data_fuenlabrada = data_sur[data_sur['level5'] == 'Fuenlabrada']
data_getafe = data_sur[data_sur['level5'] == 'Getafe']
data_leganes = data_sur[data_sur['level5'] == 'Leganés']


fig, axs = plt.subplots(2, 2, figsize=(10, 10))

axs[0, 0].scatter(data_alcorcon.index, data_alcorcon['price'])
axs[0, 0].set_title('Precios en Alcorcón')
axs[0, 0].set_xlabel('Índice')
axs[0, 0].set_ylabel('Precio')

axs[0, 1].scatter(data_fuenlabrada.index, data_fuenlabrada['price'], color = "orange")
axs[0, 1].set_title('Precios en Fuenlabrada')
axs[0, 1].set_xlabel('Índice')
axs[0, 1].set_ylabel('Precio')

axs[1, 0].scatter(data_getafe.index, data_getafe['price'], color = "black")
axs[1, 0].set_title('Precios en Getafe')
axs[1, 0].set_xlabel('Índice')
axs[1, 0].set_ylabel('Precio')

axs[1, 1].scatter(data_leganes.index, data_leganes['price'], color = "purple")
axs[1, 1].set_title('Precios en Leganés')
axs[1, 1].set_xlabel('Índice')
axs[1, 1].set_ylabel('Precio')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

data_sur_population_latitude = data_sur.groupby('level5')['latitude'].apply(list)
data_sur_population_longitude = data_sur.groupby('level5')['longitude'].apply(list)

ds_coordenadas = pd.DataFrame({
    'latitudes': data_sur_population_latitude,
    'longitudes': data_sur_population_longitude
})

ds_coordenadas = ds_coordenadas.to_dict(orient = 'index')


print(data_sur_population_latitude)
print(data_sur_population_longitude)
print(ds_coordenadas)
# Out:
# level5
# Alcorcón       [40,35059, 40,3313411, 40,3526, 40,35463262135...
# Fuenlabrada    [40,28674, 40,2853785786438, 40,2744807718156,...
# Getafe         [40,31111, 40,3060558, 40,3035689, 40,3068987,...
# Leganés        [40,31933, 40,356919, 40,3274, 40,314281186437...
# Name: latitude, dtype: object
# level5
# Alcorcón       [-3,82693, -3,8313868, -3,81587, -3,8019742213...
# Fuenlabrada    [-3,79351, -3,79508142135624, -3,7919247150421...
# Getafe         [-3,73066, -3,7346649, -3,7381336, -3,725108, ...
# Leganés        [-3,77574, -3,77769, -3,77152, -3,791686413562...
# Name: longitude, dtype: object
# ...

# %% [markdown]
# **Esto fue la creación inicial de las listas para la construcción del código, en él sólo faltó agruparlo por "level5":**
#
# lista_latitude = list(data_sur['latitude'])
# lista_longitude = list(data_sur['longitude'])
#
# coordenadas = dict(zip(lista_latitude, lista_longitude))
#
# print(data_sur[['latitude','longitude']])
# print(lista_latitude)
# print(coordenadas)
#
# **Por otra parte, no pude colocar los marcadores de las coordenadas en el mapa porque no consigo ensamblar toda la idea, con ayuda externa he podido conseguir este código:**
#
#         for zona, datos in ds_coordenadas.items():
#         latitudes = datos['latitudes']
#         longitudes = datos['longitudes']
#
#         for lat, lon in zip(latitudes, longitudes):
#             marker = marker(location=(lat, lon))
#             marker.popup = zona
#             map.add_layer(marker)
#
# map
